# %% [markdown]
# # Язык программирования Python 2025
#
# ## Домашнее задание 1 | СКБ
#
# ### Модуль 1

# %% [markdown]
# ## Разделы и баллы
#
# |#|Раздел|Баллы|
# |-|------|-----|
# |1|Numpy|20|
# |2|Matplotlib|40|
# |3|Pandas|40|
# |9|Всего|100|

# %% [markdown]
# ## Numpy [20/100]
#
# При решении задач этого раздела подразумевается максимальное использование возможностей `Numpy`.
#
# За использование любых сторонних циклов и их заменителей (итераторов, генераторов и др.) выставляется штраф.

# %% [markdown]
# ### Numpy A [10/100]
#
# В файле `data.npz` расположены два массива:
# - `nodes` - массив (N, 2), содержащий координаты точек (float)
# - `tris` - массив (M, 3), содержащий тройки индексов (i, j, k) такие, что точки с индексами i, j, k из массива `nodes` образуют треугольник
#
# Требуется:
#
# - вычислить:
#     - координаты геометрических центров треугольников
#     - минимальное и максимальное значение (среди всех треугольников):
#         - площадей
#         - углов
#         - длин сторон
#         - метрики $l_{rms} = \sqrt{\frac{1}{3} \Sigma^3_{i=1}l^2_i}$, где $l_i$ - длина $i$-й стороны треугольника
#         - долю треугольников нестандартной площади (бОльшая часть треугольников имеют одинаковую площадь с небольшой погрешностью)
# - проверить утверждение:
#     - во всех треугольниках вершины расположены по/против часовой стрелки

# %% [markdown]
# ### Numpy B [10/100]
#
# В файлах `img1.png`, `img2.png`, `img3.png` находятся зашифрованные сообщения, которые следует отыскать. Должно быть продемонстрировано изображение дешифрованного сообщения, которое можно прочитать как обычный текст, без дополнительных затруднений.
#
# Пояснения:
#
# В одном из слоев (R, G, B) изображения размещен текст сообщения, но он сильно зашумлен. Точно такой же шум, но подверженный изменениям, сохранен в другом слое изображения. Изменения включают в себя: перестановки четвертей изображения, их повороты, транспонирования, отражения, инвертирования. Ориентируясь по символам, размещенным поверх шума, нужно сделать два упомянутых выше слоя как можно более похожими друг на друга, после чего вычитание одного из другого поможет удалить шум и открыть сообщение.

# %% [markdown]
# ## Matplotlib [40/100]
#
# При решении задач этого раздела подразумевается построение графиков при помощи библиотеки `matplotlib`.

# %% [markdown]
# ## Matplotlib A [20/100]
#
# Рассчитать четыре преобразованных фигуры, состоящих из всех треугольников задачи **Numpy A**:
# - каждую фигуру вначале повернуть относительно своего геометрического центра на -90 градусов;
# - затем каждую из фигур повернуть относительно начала координат:
#   - первую фигуру - на 90 градусов,
#   - вторую фигуру - на 180 градусов,
#   - третью фигуру - на 270 градусов,
#   - четвертую фигуру - на 360 градусов.
#
# Визуализировать все четыре преобразованных фигуры на одном рисунке следующим образом:
# - точки отобразить одним цветом
# - центры треугольников цветом, отличным от цвета точек
# - треугольники (цветом треугольника показать $l_{rms}$)
# - отобразить `colorbar` для цветов треугольников

# %% [markdown]
# ### Matplotlib B [20/100]
#
# Самостоятельно сформировать нетривиальную функцию `F(x, y)` как комбинацию из:
# - функций:
#   - полиномиальных
#   - тригонометрических (обязательно)
#   - логарифм, экспонента
# - операций:
#   - арифметических `+`, `-`, `*`, `/`, `**`
#   - композиции `f(g(x, y))`
#
# Самостоятельно выбрать область `[a, b]x[c, d]`. Отрезки `[a, b]` и/или `[c, d]` должны включать в себя число $\pi$, например $[\pi/3, 2\pi/3]$
#
# Построить график `F(x, y)` в области `[a, b]x[c, d]`:
# - отобразить значения функции цветом
# - отобразить `colorbar`
# - подписать оси
# - вручную выставить засечки у осей и `colorbar` и подписи к ним
# - засечки должны использовать `tex`-нотацию и содержать число $\pi$ (на том отрезке или отрезках, которые включают число $\pi$)
# - сохранить рисунок в формате `.png` в разрежении `200 dpi` без белых полей
#
# Пример графика (в примере не хватает подписей осей):
#
# <img src="arctan_x_cos_y.png" width=400></img>

# %% [markdown]
# ## Pandas [40/100]
#
# При решении задач этого раздела подразумевается максимальное использование возможностей `pandas` и допускается использование `numpy`.
#
# За использование любых сторонних циклов и их заменителей (итераторов, генераторов и др.) выставляется штраф.

# %% [markdown]
# ### Pandas A [20/100]
#
# В файле `fin_v2.csv` находятся записи о доходах и расходах физического лица.
#
# Требуется рассчитать/построить:
#
# 1. график среднемесячного дохода для каждого года,
# 2. график среднемесячного расхода для каждого года,
# 3. состояние счета физического лица на каждый день и изобразить график (считать, что в начальный момент времени состояние счета было нулевым),
# 4. первую и последнюю даты, когда счет был отрицательным,
# 5. 5 дат, когда произошли самые большие траты и их категории и величины,
# 6. построить прогноз (линейный и квадратичный) состояния счета через год после последней записи (отобразить в виде графиков),
# 7. выбросить из данных две самых больших траты и снова построить прогнозы (отобразить в виде графиков).

# %% [markdown]
# ### Pandas B [20/100]
#
# В файле `students.csv` находится список студентов.
# В файле `grades.csv` - оценки за контрольную работу.
#
# Столбец `hash` однозначно идентифицирует студента.
#
# Контрольная работа состояла из 8 заданий. Веса всех заданий - одинаковые.
#
# Требуется ответить на вопросы / вычислить:
# - кто написал контрольную работу, а кто - нет?
# - средняя оценка по каждому заданию у каждой группы? по всем заданиям у каждой группы?
# - топ-5 лидеров и топ-5 отстающих.
#
# По информации об оценках (считая, что каждому студенту соответствует вектор оценок):
#
# - выделить 2 главных компоненты при помощи `sklearn.decomposition.PCA`;
# - разбить на 4 кластера при помощи `sklearn.cluster.k_means`;
# - визуализировать результат при помощи`plt.scatter`, используя в качестве цвета номер кластера;
# - на том же рисунке отметить центр кластера и подписать его номер;
# - вычислить для каждого кластера среднюю и медианную оценки;
# - для каждого кластера вывести номера групп.
